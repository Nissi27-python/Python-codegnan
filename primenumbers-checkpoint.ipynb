# %%
n=int(input())
res=[]
for i in range(1,n+1):
    if n % i == 0:
      res.append(i)
print(res)
if len(res) == 2:
    print("prime")
else:
    print("not prime")
# Out:
#  10
# [1, 2, 5, 10]
# not prime

# %%
n=int(input())
res=[]
for i in range(2,n//2+1):
    if n % i == 0:
      print(n,"is not a prime number")
      break
else:
    print(n,"is prime number")
# Out:
#  7
# 7 is prime number
