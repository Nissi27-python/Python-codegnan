# %%
class Bank:
    def __init__(self,username, password, amount):
        self.username = username #public attributue
        self._password = password #protected attribute
        self.__amount = amount #private attribute
    def withdraw(self, withdraw_amount):#public method
        if self.__amount >= withdraw_amount:
            self.__amount -= withdraw_amount
            return f"withdraw successful and current balance is {self.__amount}"
        else:
            return "Insufficient amount"
    def deposite(self, deposite_amount):#public method
    
            self.__amount += deposite_amount
            return f"{deposite_amount} is deposited successful and current balance is {self.__amount}"
    
    def __total_users(self): #private method
         return "Total users are 101"
#creating object for bank
b = Bank('nissi','zesi',1000)
print(b.username)
print(b.deposite(100))
print(b.withdraw(10))
print(b._password)#protected member access
print(b._Bank__amount)##private member accessing using name mangling
print(b._Bank__total_users())##private method accessing using name mangling
# Out:
# nissi
# 100 is deposited successful and current balance is 1100
# withdraw successful and current balance is 1090
# zesi
# 1090
# Total users are 101
